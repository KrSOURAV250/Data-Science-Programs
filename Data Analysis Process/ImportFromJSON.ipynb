# %%
import pandas as pd
import requests

# %%
response = requests.get(
    "https://api.themoviedb.org/3/movie/top_rated?api_key=14cb3aa18123646d9ea2c4ac6100dab7&language=en-US&page=1")

# %%
df = pd.DataFrame(response.json()["results"])[
    ["id", "title", "overview", "release_date", "popularity", "vote_average", "vote_count"]]
df
# Out:
#         id                                          title  \
# 0      238                                  The Godfather
# 1      278                       The Shawshank Redemption
# 2   772071                               Cuando Sea Joven
# 3   995133       The Boy, the Mole, the Fox and the Horse
# 4      240                          The Godfather Part II
# 5      424                               Schindler's List
# 6    19404                    Dilwale Dulhania Le Jayenge
# 7      129                                  Spirited Away
# 8      389                                   12 Angry Men
# 9   372058                                     Your Name.
# 10  496243                                       Parasite
# 11     155                                The Dark Knight
# 12     497                                 The Green Mile
# 13     680                                   Pulp Fiction
# 14     429                 The Good, the Bad and the Ugly
# ...

# %%
df = pd.DataFrame()
for i in range(1, 20):
    response = requests.get(
        rf"https://api.themoviedb.org/3/movie/top_rated?api_key=14cb3aa18123646d9ea2c4ac6100dab7&language=en-US&page={i}")
    temp_df = pd.DataFrame(response.json()["results"])[
        ["id", "title", "overview", "release_date", "popularity", "vote_average", "vote_count"]]
    df = pd.concat([df, temp_df], ignore_index=True)

# %%
df
# Out:
#          id                                     title  \
# 0       238                             The Godfather
# 1       278                  The Shawshank Redemption
# 2    772071                          Cuando Sea Joven
# 3    995133  The Boy, the Mole, the Fox and the Horse
# 4       240                     The Godfather Part II
# ..      ...                                       ...
# 375  360814                                    Dangal
# 376   15383                           Army of Shadows
# 377     775                        A Trip to the Moon
# 378   10404                     Raise the Red Lantern
# 379  667520                            A Whisker Away
#
#                                               overview release_date  \
# 0    Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 1    Framed in the 1940s for the double murder of h...   1994-09-23
# 2    70-year-old Malena gets a second chance at lif...   2022-09-14
# ...

# %% [markdown]
# # End
